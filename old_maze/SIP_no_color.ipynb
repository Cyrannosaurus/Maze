# %%
import random as rand, numpy as np, os, sys
from collections import deque

# %%
class Node():
    def __init__(self, state, parent, action, distance_to):
        self.state = state
        self.parent = parent
        self.action = action
        if parent is None:
            self.distance_travelled = 0
        else:
            self.distance_travelled = self.parent.distance_travelled + 1
        self.distance_to = distance_to

# %%
class StackFrontier():
    def __init__(self):
        self.frontier = deque()
    
    def add(self, node:Node):
        self.frontier.append(node)

    def contains_state(self, state):
        return any(node.state == state for node in self.frontier)

    def empty(self):
        return len(self.frontier) == 0

    def size(self):
        return len(self.frontier)

    def pop(self):
        if self.empty():
            raise Exception('Frontier is empty')
        else:
            return self.frontier.popleft()


class QueueFrontier():
    def __init__(self):
        self.frontier = []
    
    def add(self, node:Node):
        self.frontier.append(node)

    def contains_state(self, state):
        return any(node.state == state for node in self.frontier)

    def empty(self):
        return len(self.frontier) == 0

    def size(self):
        return len(self.frontier)

    def pop(self):
        if self.empty():
            raise Exception('Frontier is empty')
        else:
            return self.frontier.pop(0)


class AStarFrontier():
    def __init__(self):
        self.frontier = []
    def add(self, node: Node):
        self.frontier.append(node)

    def contains_state(self, state):
        return any(node.state == state for node in self.frontier)
    
    def empty(self):
        return len(self.frontier) == 0

    def size(self):
        return len(self.frontier)
        
    def pop(self):
        if self.empty():
            raise Exception("Frontier is empty")
        else:
            minDist = sys.maxsize
            for i, node in enumerate(self.frontier):
                if node.distance_travelled + node.distance_to < minDist:
                    retIndex = i
                    minDist = node.distance_travelled + node.distance_to
            return self.frontier.pop(retIndex)
    

class GreedyFrontier():
    def __init__(self):
        self.frontier = []
    def add(self, node: Node):
        self.frontier.append(node)

    def contains_state(self, state):
        return any(node.state == state for node in self.frontier)
    
    def empty(self):
        return len(self.frontier) == 0

    def size(self):
        return len(self.frontier)
        
    def pop(self):
        if self.empty():
            raise Exception("Frontier is empty")
        else:
            minDist = 999999
            for i, node in enumerate(self.frontier):
                if node.distance_to < minDist:
                    retIndex = i
                    minDist = node.distance_to
            return self.frontier.pop(retIndex)


class LearnedFrontier():
    def __init__(self, bias = rand.randint(0,1), dtr_weight = rand.randint(0,1), dt_weight = rand.randint(0,1)):
        self.bias = bias
        self.dist_trav_weight = dtr_weight
        self.dist_to_weight = dt_weight

    def add(self, node:Node):
        self.frontier.append(node)

    def contains_state(self, state):
        return any(node.state == state for node in self.frontier)

    def empty(self):
        return len(self.frontier) == 0

    def size(self):
        return len(self.frontier)

    def pop(self):
        if self.empty():
            raise Exception('Frontier is empty')
        else:
            minDist = 999999
            for i, node in enumerate(self.frontier):
                if node.distance_to < minDist:
                    retIndex = i
                    minDist = self.bias + self.dist_to_weight * node.distance_to + self.dist_trav_weight * node.distance_travelled
            return self.frontier.pop(retIndex)

# %%
class Maze():
    def __init__(self, walls = [], start = None, goal = None):

        self.walls = walls # 2D bool array
        self.width = max(len(row) for row in walls) if walls != [] else 0
        self.height = len(walls)
        self.start = start
        self.goal = goal

    def read_maze(self, filename:str):
        # Read file
        with open(filename, 'r') as f:
            contents = f.read()
        
        if contents.count('A') != 1:
            raise Exception("Maze needs a single startpoint")
        if contents.count('B') != 1:
            raise Exception("Maze needs a single endpoint")

        contents = contents.splitlines()
        # Record height and width of maze
        self.height = len(contents)
        self.width = max(len(line) for line in contents)

        # Add context
        self.walls = [] # 2D bool array
        for r in range(self.height):
            row = []
            for c in range(self.width):
                # Try block as not all mazes will be rectangular
                try:
                    if contents[r][c] == '#':
                        row.append(True)
                    elif contents[r][c] == ' ':
                        row.append(False)
                    elif contents[r][c] == 'A':
                        self.start = (r,c)
                        row.append(False)
                    elif contents[r][c] == 'B':
                        self.goal = (r,c)
                        row.append(False)
                    else:
                        row.append(True)
                except IndexError:
                    row.append(True)
            self.walls.append(row)
        self.solution = None

    def get_distance(self, state1:tuple, state2:tuple):
        return abs(state1[0] - state2[0]) + abs(state1[1] - state2[1])

    def write_maze(self, maze_name:str):
        new_maze = open(maze_name, 'w')
        new_maze.write('Dimensions: (' + str(self.height) + ',' + str(self.width) + ')\n')
        for r in range(self.height):
            for c in range(self.width):
                if self.walls[r][c] == True:
                    new_maze.write('#')
                elif (r,c) == self.start:
                    new_maze.write('A')
                elif (r,c) == self.goal:
                    new_maze.write('B')
                else:
                    new_maze.write(' ')

            new_maze.write('\n')
        new_maze.close()

# %%
class Agent():
    def __init__(self, frontier):
        self.current_state = None
        self.explored = set()
        self.frontier = frontier
    
    def neighbors(self, maze:Maze):
        row, col = self.current_state
        # All possible actions
        candidates = [
            ('up', (row-1, col)),
            ('down', (row+1, col)),
            ('left', (row, col-1)),
            ('right', (row, col+1)),
        ]
        # Validate actions
        possible = []
        for action, (row, col) in candidates:
            try:
                if not maze.walls[row][col]:
                    possible.append((action, (row, col)))
            except IndexError:
                continue
        return possible

    def solve(self, maze:Maze):
        # Keep track of how many states have been explored (performance measure)
        # self.num_explored = 0

        # Initialize frontier to the starting position
        start = Node(state=maze.start, parent=None, action=None, distance_to=maze.get_distance(maze.start, maze.goal))
        self.frontier.add(start)


        # Search for solution
        while True:
            if self.frontier.empty():
                # cprint('No solution', 'red', end='\n\n')
                # print('No Solution', end='')
                return False
            node = self.frontier.pop()
            self.current_state = node.state
            if self.current_state == maze.goal:
                # Add to explored
                self.explored.add(self.current_state)
                # cprint('Solved!', 'green', end='\n\n')
                # print('Solved!', end='')
                actions = []
                cells = []

                # Follow breadcrumbs to remake solution path
                while node.parent is not None:
                    actions.append(node.action)
                    cells.append(node.state)
                    node = node.parent
                # B -> A --> A -> B
                actions.reverse()
                cells.reverse()
                maze.solution = (actions, cells)
                return len(cells)
            # Add to explored
            self.explored.add(self.current_state)

            # Add neighbors to frontier
            for action, state in self.neighbors(maze):
                if not self.frontier.contains_state(state):
                    if state not in self.explored: 
                        child = Node(state=state, parent=node, action=action, distance_to=maze.get_distance(state, maze.goal))
                        self.frontier.add(child)
            
    def print_solution(self, maze:Maze, fog_of_war:bool = False):
        for row in range(maze.height):
            for col in range(maze.width):
                if fog_of_war:
                    if (row,col) in self.explored:
                        if (row,col) == maze.start:
                            # cprint('A', 'cyan', end='')
                            print('A', end='')
                        elif (row,col) == maze.goal:
                            # cprint('B', 'cyan', end='')
                            print('B', end='')
                        elif maze.walls[row][col] == True:
                            print('#', end='')
                        elif maze.solution is not None and (row,col) in maze.solution[1]: ##########
                            # cprint('*', 'green', end='')
                            print('*', end='')
                        elif (row,col) in self.explored:
                            # cprint('e', 'red', end='')
                            print('e', end='')
                        else:
                            print(' ', end='')
                    else:
                        print('?', end='')
                else:
                    if (row,col) == maze.start:
                        # cprint('A', 'cyan', end='')
                        print('A', end='')
                    elif (row,col) == maze.goal:
                        # cprint('B', 'cyan', end='')
                        print('B', end='')
                    elif maze.walls[row][col] == True:
                        print('#', end='')
                    elif maze.solution is not None and (row,col) in maze.solution[1]: ##########
                        # cprint('*', 'green', end='')
                        print('*', end='')
                    elif (row,col) in self.explored:
                        # cprint('e', 'red', end='')
                        print('e', end='')
                    else:
                        print(' ', end='')
            print()
        print()

        actions, cells = maze.solution
        print('States explored: ' + str(len(self.explored)))
        print('Length of solution: ' + str(len(actions)))

# %%
class MazeGenerator():
    def __init__(self, maze:Maze, min_dimensions:tuple, max_dimensions:tuple, min_path_length:int, start_num:int=0):
        self.maze = maze
        self.min_height, self.min_width = min_dimensions
        self.max_height, self.max_width = max_dimensions
        self.min_path_length = min_path_length
        self.start_num = start_num

    def generate(self, num_maps):
        def feature_given_int(key:int):
            feature_dict = {
                0:' ',
                1:'#'
            }
            return feature_dict[key]
        
        def verify(maze_name:str):
            maze = InfoMaze(maze_name)
            solver = Agent(AStarFrontier())
            return solver.solve(maze)

        generated = self.start_num
        while generated < num_maps + self.start_num:
            map_name = 'gmap' + str(generated) + '.txt'
            height = rand.randint(self.min_height, self.max_height)
            width = rand.randint(self.min_width, self.max_width)
            start_pos = (rand.randint(0, height - 1), rand.randint(1, width))
            goal_pos = (rand.randint(0, height - 1), rand.randint(1, width))
            if goal_pos == start_pos:
                goal_pos = (rand.randint(0, height), rand.randint(1, width))
            print('Map specs: ' + map_name + '\n Dimensions=(' + str(height) + ',' + str(width) + ')\n')
            is_maze = False
            while is_maze == False:
                new_map = open(map_name, 'w')
                new_map.write('Dimensions: (' + str(height) + ',' + str(width) + ')\n')
                new_map.write('#' * (width + 2) + '\n')
                for r in range(height):
                    for c in range(width + 2):
                        if c == 0 or c == width + 1:
                            new_map.write('#')
                        elif (r,c) == start_pos:
                            new_map.write('A')
                        elif (r,c) == goal_pos:
                            new_map.write('B')
                        else:
                            new_map.write(feature_given_int(rand.randint(0,1)))
                    new_map.write('\n')
                new_map.write('#' * (width + 2) + '\n')
                new_map.close()
                test_result = verify(map_name)
                if test_result == False:
                    continue
                elif test_result < self.min_path_length:
                    continue
                else:
                    test_map = open(map_name, 'a')
                    test_map.write('Optimal path length: ' + str(test_result))
                    test_map.close()
                    print('Maze found')
                    is_maze = True
            generated += 1

# %%
class MazeGenerator2():
    def __init__(self, min_dimensions:tuple, max_dimensions:tuple, min_path_length:int, start_num:int=0):
        self.maze = None
        self.min_height, self.min_width = min_dimensions
        self.max_height, self.max_width = max_dimensions
        self.min_path_length = min_path_length
        self.start_num = start_num

    def generate(self, num_maps):
        def feature_given_int(key:int):
            feature_dict = {
                0:False,
                1:True
            }
            return feature_dict[key]
        
        def verify(generator:MazeGenerator2, bwalls:list, start:tuple, goal:tuple):
            generator.maze = Maze(bwalls, start, goal)
            solver = Agent(AStarFrontier())
            return solver.solve(generator.maze)

        generated = self.start_num
        while generated < num_maps + self.start_num:
            map_name = 'gmap' + str(generated) + '.txt'
            height = rand.randint(self.min_height, self.max_height)
            width = rand.randint(self.min_width, self.max_width)
            start_pos = (rand.randint(0, height), rand.randint(1, width))
            goal_pos = (rand.randint(0, height), rand.randint(1, width))
            if goal_pos == start_pos:
                goal_pos = (rand.randint(0, height), rand.randint(1, width))
            print(f'Map specs: {map_name}\n Dimensions=({height},{width})\n')
            is_maze = False
            creation_attempts = 0
            while is_maze == False:
                walls = []
                for r in range(height + 2):
                    row = []
                    for c in range(width + 2):
                        if c == 0 or c == width + 1 or r == 0 or r == height + 1:
                            row.append(True)
                        elif (r - 1,c) == start_pos:
                            row.append(False)
                        elif (r - 1,c) == goal_pos:
                            row.append(False)
                        else:
                            row.append(feature_given_int(rand.randint(0,1)))
                    walls.append(row)
                test_result = verify(self, bwalls=walls, start=start_pos, goal=goal_pos)
                creation_attempts += 1
                if test_result == False:
                    print(f'Generation {creation_attempts} was unsolvable')
                    continue
                elif test_result < self.min_path_length:
                    print(f'Generation {creation_attempts} had a solution length less than the minimum threshold')
                    continue
                else:
                    self.maze.write_maze(map_name)
                    test_map = open(map_name, 'a')
                    test_map.write(f'Optimal path length: {test_result}')
                    test_map.close()
                    print(f'Generation {creation_attempts} successfully made a maze')
                    is_maze = True
            generated += 1

# %%
mgen = MazeGenerator2((5,5), (10,10), 5, 254)
mgen.generate(25)
# Out:
# neration 48395 was unsolvable
# Generation 48396 had a solution length less than the minimum threshold
# Generation 48397 had a solution length less than the minimum threshold
# Generation 48398 had a solution length less than the minimum threshold
# Generation 48399 was unsolvable
# Generation 48400 had a solution length less than the minimum threshold
# Generation 48401 had a solution length less than the minimum threshold
# Generation 48402 was unsolvable
# Generation 48403 was unsolvable
# Generation 48404 was unsolvable
# Generation 48405 had a solution length less than the minimum threshold
# Generation 48406 had a solution length less than the minimum threshold
# Generation 48407 had a solution length less than the minimum threshold
# Generation 48408 was unsolvable
# Generation 48409 was unsolvable
# Generation 48410 was unsolvable
# Generation 48411 was unsolvable
# Generation 48412 had a solution length less than the minimum threshold
# Generation 48413 was unsolvable
# Generation 48414 had a solution length less than the minimum threshold
# Generation 48415 was unsolvable
# Generation 48416 was unsolvable
# Generation 48417 was unsolvable
# Generation 48418 had a solution length less than the minimum threshold
# Generation 48419 had a solution length less than the minimum threshold
# Generation 48420 had a solution length less than the minimum threshold
# Generation 48421 was unsolvable
# Generation 48422 was unsolvable
# Generation 48423 had a solution length less than the minimum threshold
# Generation 48424 was unsolvable
# Generation 48425 was unsolvable
# Generation 48426 was unsolvable
# Generation 48427 was unsolvable
# Generation 48428 was unsolvable
# Generation 48429 had a solution length less than the minimum threshold
# Generation 48430 had a solution length less than the minimum threshold
# Generation 48431 had a solution length less than the minimum threshold
# Generation 48432 had a solution length less than the minimum threshold
# Generation 48433 had a solution length less than the minimum threshold
# Generation 48434 had a solution length less than the minimum threshold
# Generation 48435 was unsolvable
# Generation 48436 had a solution length less than the minimum threshold
# Generation 48437 had a solution length less than the minimum threshold
# Generation 48438 had a solution length less than the minimum threshold
# Generation 48439 was unsolvable
# Generation 48440 had a solution length less than the minimum threshold
# Generation 48441 had a solution length less than the minimum threshold
# Generation 48442 was unsolvable
# Generation 48443 had a solution length less than the minimum threshold
# Generation 48444 was unsolvable
# Generation 48445 was unsolvable
# Generation 48446 had a solution length less than the minimum threshold
# Generation 48447 had a solution length less than the minimum threshold
# Generation 48448 had a solution length less than the minimum threshold
# Generation 48449 was unsolvable
# Generation 48450 was unsolvable
# Generation 48451 had a solution length less than the minimum threshold
# Generation 48452 had a solution length less than the minimum threshold
# Generation 48453 was unsolvable
# Generation 48454 had a solution length less than the minimum threshold
# Generation 48455 was unsolvable
# Generation 48456 had a solution length less than the minimum threshold
# Generation 48457 had a solution length less than the minimum threshold
# Generation 48458 was unsolvable
# Generation 48459 was unsolvable
# Generation 48460 was unsolvable
# Generation 48461 was unsolvable
# Generation 48462 was unsolvable
# Generation 48463 was unsolvable
# Generation 48464 had a solution length less than the minimum threshold
# Generation 48465 was unsolvable
# Generation 48466 had a solution length less than the minimum threshold
# Generation 48467 had a solution length less than the minimum threshold
# Generation 48468 was unsolvable
# Generation 48469 was unsolvable
# Generation 48470 was unsolvable
# Generation 48471 had a solution length less than the minimum threshold
# Generation 48472 had a solution length less than the minimum threshold
# Generation 48473 had a solution length less than the minimum threshold
# Generation 48474 was unsolvable
# Generation 48475 was unsolvable
# Generation 48476 had a solution length less than the minimum threshold
# Generation 48477 had a solution length less than the minimum threshold
# Generation 48478 had a solution length less than the minimum threshold
# Generation 48479 was unsolvable
# Generation 48480 had a solution length less than the minimum threshold
# Generation 48481 had a solution length less than the minimum threshold
# Generation 48482 had a solution length less than the minimum threshold
# Generation 48483 had a solution length less than the minimum threshold
# Generation 48484 was unsolvable
# Generation 48485 was unsolvable
# Generation 48486 had a solution length less than the minimum threshold
# Generation 48487 had a solution length less than the minimum threshold
# Generation 48488 was unsolvable
# Generation 48489 had a solution length less than the minimum threshold
# Generation 48490 was unsolvable
# Generation 48491 was unsolvable
# Generation 48492 was unsolvable
# Generation 48493 had a solution length less than the minimum threshold
# Generation 48494 was unsolvable
# Generation 48495 was unsolvable
# Generation 48496 was unsolvable
# Generation 48497 had a solution length less than the minimum threshold
# Generation 48498 was unsolvable
# Generation 48499 had a solution length less than the minimum threshold
# Generation 48500 had a solution length less than the minimum threshold
# Generation 48501 was unsolvable
# Generation 48502 had a solution length less than the minimum threshold
# Generation 48503 was unsolvable
# Generation 48504 was unsolvable
# Generation 48505 was unsolvable
# Generation 48506 had a solution length less than the minimum threshold
# Generation 48507 was unsolvable
# Generation 48508 was unsolvable
# Generation 48509 had a solution length less than the minimum threshold
# Generation 48510 had a solution length less than the minimum threshold
# Generation 48511 had a solution length less than the minimum threshold
# Generation 48512 had a solution length less than the minimum threshold
# Generation 48513 was unsolvable
# Generation 48514 was unsolvable
# Generation 48515 had a solution length less than the minimum threshold
# Generation 48516 was unsolvable
# Generation 48517 was unsolvable
# Generation 48518 had a solution length less than the minimum threshold
# Generation 48519 was unsolvable
# Generation 48520 had a solution length less than the minimum threshold
# Generation 48521 had a solution length less than the minimum threshold
# Generation 48522 had a solution length less than the minimum threshold
# Generation 48523 had a solution length less than the minimum threshold
# Generation 48524 was unsolvable
# Generation 48525 had a solution length less than the minimum threshold
# Generation 48526 had a solution length less than the minimum threshold
# Generation 48527 had a solution length less than the minimum threshold
# Generation 48528 was unsolvable
# Generation 48529 had a solution length less than the minimum threshold
# Generation 48530 was unsolvable
# Generation 48531 had a solution length less than the minimum threshold
# Generation 48532 had a solution length less than the minimum threshold
# Generation 48533 was unsolvable
# Generation 48534 had a solution length less than the minimum threshold
# Generation 48535 was unsolvable
# Generation 48536 was unsolvable
# Generation 48537 had a solution length less than the minimum threshold
# Generation 48538 had a solution length less than the minimum threshold
# Generation 48539 was unsolvable
# Generation 48540 had a solution length less than the minimum threshold
# Generation 48541 had a solution length less than the minimum threshold
# Generation 48542 was unsolvable
# Generation 48543 had a solution length less than the minimum threshold
# Generation 48544 was unsolvable
# Generation 48545 was unsolvable
# Generation 48546 was unsolvable
# Generation 48547 had a solution length less than the minimum threshold
# Generation 48548 had a solution length less than the minimum threshold
# Generation 48549 had a solution length less than the minimum threshold
# Generation 48550 was unsolvable
# Generation 48551 was unsolvable
# Generation 48552 was unsolvable
# Generation 48553 was unsolvable
# Generation 48554 had a solution length less than the minimum threshold
# Generation 48555 was unsolvable
# Generation 48556 was unsolvable
# Generation 48557 was unsolvable
# Generation 48558 was unsolvable
# Generation 48559 was unsolvable
# Generation 48560 had a solution length less than the minimum threshold
# Generation 48561 had a solution length less than the minimum threshold
# Generation 48562 had a solution length less than the minimum threshold
# Generation 48563 was unsolvable
# Generation 48564 had a solution length less than the minimum threshold
# Generation 48565 had a solution length less than the minimum threshold
# Generation 48566 had a solution length less than the minimum threshold
# Generation 48567 was unsolvable
# Generation 48568 had a solution length less than the minimum threshold
# Generation 48569 was unsolvable
# Generation 48570 had a solution length less than the minimum threshold
# Generation 48571 had a solution length less than the minimum threshold
# Generation 48572 had a solution length less than the minimum threshold
# Generation 48573 was unsolvable
# Generation 48574 had a solution length less than the minimum threshold
# Generation 48575 had a solution length less than the minimum threshold
# Generation 48576 had a solution length less than the minimum threshold
# Generation 48577 had a solution length less than the minimum threshold
# Generation 48578 was unsolvable
# Generation 48579 had a solution length less than the minimum threshold
# Generation 48580 was unsolvable
# Generation 48581 had a solution length less than the minimum threshold
# Generation 48582 was unsolvable
# Generation 48583 was unsolvable
# Generation 48584 had a solution length less than the minimum threshold
# Generation 48585 had a solution length less than the minimum threshold
# Generation 48586 was unsolvable
# Generation 48587 had a solution length less than the minimum threshold
# Generation 48588 had a solution length less than the minimum threshold
# Generation 48589 was unsolvable
# Generation 48590 was unsolvable
# Generation 48591 was unsolvable
# Generation 48592 was unsolvable
# Generation 48593 was unsolvable
# Generation 48594 had a solution length less than the minimum threshold
# Generation 48595 had a solution length less than the minimum threshold
# Generation 48596 was unsolvable
# Generation 48597 had a solution length less than the minimum threshold
# Generation 48598 was unsolvable
# Generation 48599 had a solution length less than the minimum threshold
# Generation 48600 was unsolvable
# Generation 48601 was unsolvable
# Generation 48602 was unsolvable
# Generation 48603 was unsolvable
# Generation 48604 had a solution length less than the minimum threshold
# Generation 48605 was unsolvable
# Generation 48606 was unsolvable
# Generation 48607 had a solution length less than the minimum threshold
# Generation 48608 was unsolvable
# Generation 48609 was unsolvable
# Generation 48610 had a solution length less than the minimum threshold
# Generation 48611 had a solution length less than the minimum threshold
# Generation 48612 had a solution length less than the minimum threshold
# Generation 48613 had a solution length less than the minimum threshold
# Generation 48614 was unsolvable
# Generation 48615 was unsolvable
# Generation 48616 had a solution length less than the minimum threshold
# Generation 48617 was unsolvable
# Generation 48618 was unsolvable
# Generation 48619 had a solution length less than the minimum threshold
# Generation 48620 was unsolvable
# Generation 48621 had a solution length less than the minimum threshold
# Generation 48622 had a solution length less than the minimum threshold
# Generation 48623 had a solution length less than the minimum threshold
# Generation 48624 had a solution length less than the minimum threshold
# Generation 48625 had a solution length less than the minimum threshold
# Generation 48626 was unsolvable
# Generation 48627 was unsolvable
# Generation 48628 was unsolvable
# Generation 48629 had a solution length less than the minimum threshold
# Generation 48630 was unsolvable
# Generation 48631 was unsolvable
# Generation 48632 had a solution length less than the minimum threshold
# Generation 48633 was unsolvable
# Generation 48634 was unsolvable
# Generation 48635 was unsolvable
# Generation 48636 had a solution length less than the minimum threshold
# Generation 48637 was unsolvable
# Generation 48638 had a solution length less than the minimum threshold
# Generation 48639 was unsolvable
# Generation 48640 had a solution length less than the minimum threshold
# Generation 48641 was unsolvable
# Generation 48642 was unsolvable
# Generation 48643 was unsolvable
# Generation 48644 had a solution length less than the minimum threshold
# Generation 48645 had a solution length less than the minimum threshold
# Generation 48646 was unsolvable
# Generation 48647 had a solution length less than the minimum threshold
# Generation 48648 had a solution length less than the minimum threshold
# Generation 48649 had a solution length less than the minimum threshold
# Generation 48650 had a solution length less than the minimum threshold
# Generation 48651 had a solution length less than the minimum threshold
# Generation 48652 was unsolvable
# Generation 48653 had a solution length less than the minimum threshold
# Generation 48654 had a solution length less than the minimum threshold
# Generation 48655 had a solution length less than the minimum threshold
# Generation 48656 had a solution length less than the minimum threshold
# Generation 48657 had a solution length less than the minimum threshold
# Generation 48658 was unsolvable
# Generation 48659 had a solution length less than the minimum threshold
# Generation 48660 had a solution length less than the minimum threshold
# Generation 48661 was unsolvable
# Generation 48662 was unsolvable
# Generation 48663 was unsolvable
# Generation 48664 had a solution length less than the minimum threshold
# Generation 48665 was unsolvable
# Generation 48666 had a solution length less than the minimum threshold
# Generation 48667 had a solution length less than the minimum threshold
# Generation 48668 had a solution length less than the minimum threshold
# Generation 48669 had a solution length less than the minimum threshold
# Generation 48670 was unsolvable
# Generation 48671 had a solution length less than the minimum threshold
# Generation 48672 had a solution length less than the minimum threshold
# Generation 48673 was unsolvable
# Generation 48674 was unsolvable
# Generation 48675 was unsolvable
# Generation 48676 had a solution length less than the minimum threshold
# Generation 48677 had a solution length less than the minimum threshold
# Generation 48678 had a solution length less than the minimum threshold
# Generation 48679 was unsolvable
# Generation 48680 had a solution length less than the minimum threshold
# Generation 48681 was unsolvable
# Generation 48682 was unsolvable
# Generation 48683 had a solution length less than the minimum threshold
# Generation 48684 had a solution length less than the minimum threshold
# Generation 48685 was unsolvable
# Generation 48686 had a solution length less than the minimum threshold
# Generation 48687 was unsolvable
# Generation 48688 had a solution length less than the minimum threshold
# Generation 48689 was unsolvable
# Generation 48690 had a solution length less than the minimum threshold
# Generation 48691 had a solution length less than the minimum threshold
# Generation 48692 had a solution length less than the minimum threshold
# Generation 48693 had a solution length less than the minimum threshold
# Generation 48694 was unsolvable
# Generation 48695 had a solution length less than the minimum threshold
# Generation 48696 was unsolvable
# Generation 48697 was unsolvable
# Generation 48698 was unsolvable
# Generation 48699 was unsolvable
# Generation 48700 was unsolvable
# Generation 48701 was unsolvable
# Generation 48702 was unsolvable
# Generation 48703 had a solution length less than the minimum threshold
# Generation 48704 was unsolvable
# Generation 48705 was unsolvable
# Generation 48706 had a solution length less than the minimum threshold
# Generation 48707 had a solution length less than the minimum threshold
# Generation 48708 was unsolvable
# Generation 48709 had a solution length less than the minimum threshold
# Generation 48710 was unsolvable
# Generation 48711 had a solution length less than the minimum threshold
# Generation 48712 was unsolvable
# Generation 48713 had a solution length less than the minimum threshold
# Generation 48714 was unsolvable
# Generation 48715 had a solution length less than the minimum threshold
# Generation 48716 was unsolvable
# Generation 48717 had a solution length less than the minimum threshold
# Generation 48718 had a solution length less than the minimum threshold
# Generation 48719 was unsolvable
# Generation 48720 was unsolvable
# Generation 48721 had a solution length less than the minimum threshold
# Generation 48722 had a solution length less than the minimum threshold
# Generation 48723 had a solution length less than the minimum threshold
# Generation 48724 was unsolvable
# Generation 48725 was unsolvable
# Generation 48726 had a solution length less than the minimum threshold
# Generation 48727 was unsolvable
# Generation 48728 was unsolvable
# Generation 48729 was unsolvable
# Generation 48730 was unsolvable
# Generation 48731 was unsolvable
# Generation 48732 had a solution length less than the minimum threshold
# Generation 48733 was unsolvable
# Generation 48734 had a solution length less than the minimum threshold
# Generation 48735 was unsolvable
# Generation 48736 had a solution length less than the minimum threshold
# Generation 48737 was unsolvable
# Generation 48738 had a solution length less than the minimum threshold
# Generation 48739 was unsolvable
# Generation 48740 was unsolvable
# Generation 48741 had a solution length less than the minimum threshold
# Generation 48742 had a solution length less than the minimum threshold
# Generation 48743 had a solution length less than the minimum threshold
# Generation 48744 had a solution length less than the minimum threshold
# Generation 48745 had a solution length less than the minimum threshold
# Generation 48746 was unsolvable
# Generation 48747 had a solution length less than the minimum threshold
# Generation 48748 had a solution length less than the minimum threshold
# Generation 48749 had a solution length less than the minimum threshold
# Generation 48750 was unsolvable
# Generation 48751 was unsolvable
# Generation 48752 had a solution length less than the minimum threshold
# Generation 48753 was unsolvable
# Generation 48754 had a solution length less than the minimum threshold
# Generation 48755 had a solution length less than the minimum threshold
# Generation 48756 was unsolvable
# Generation 48757 was unsolvable
# Generation 48758 was unsolvable
# Generation 48759 had a solution length less than the minimum threshold
# Generation 48760 was unsolvable
# Generation 48761 had a solution length less than the minimum threshold
# Generation 48762 had a solution length less than the minimum threshold
# Generation 48763 had a solution length less than the minimum threshold
# Generation 48764 was unsolvable
# Generation 48765 was unsolvable
# Generation 48766 was unsolvable
# Generation 48767 had a solution length less than the minimum threshold
# Generation 48768 was unsolvable
# Generation 48769 had a solution length less than the minimum threshold
# Generation 48770 was unsolvable
# Generation 48771 had a solution length less than the minimum threshold
# Generation 48772 had a solution length less than the minimum threshold
# Generation 48773 was unsolvable
# Generation 48774 had a solution length less than the minimum threshold
# Generation 48775 was unsolvable
# Generation 48776 was unsolvable
# Generation 48777 had a solution length less than the minimum threshold
# Generation 48778 was unsolvable
# Generation 48779 had a solution length less than the minimum threshold

# %%
#mlazer2 = Maze()
#mlazer2.read_file('maze3.txt')
#rational = Agent(GreedyFrontier())
#rational.solve(mlazer2)
#rational.print_solution(mlazer2, fog_of_war=False)

# %%
f = open('gmap0.txt')
f.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-27-939682055ba7> in <module>
# ----> 1 f = open('gmap0.txt')
#       2 f.close()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'gmap0.txt'

# %%
mgen.maze.write_maze('broke.txt')
print(mgen.maze.goal)
print(mgen.maze.walls)
# Out:
# (0, 3)
# [[True, True, True, True, True, True, True, True, True, True, True, True], [True, False, False, False, False, True, False, False, False, False, True, True], [True, True, False, True, True, True, False, True, False, False, False, True], [True, True, True, False, True, False, True, False, False, False, False, True], [True, False, True, False, True, False, False, False, True, False, True, True], [True, False, False, False, False, False, True, True, True, False, False, True], [True, False, False, True, True, False, True, True, True, True, True, True], [True, True, True, True, True, True, True, True, True, True, True, True]]
